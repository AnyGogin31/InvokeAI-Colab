# %%
bypass_file_name = "Iv_k_AI"

# !wget -q https://raw.githubusercontent.com/AnyGogin31/InvokeAI-Colab/main/InvokeAI_GColab.ipynb -O {bypass_file_name}.ibynb

# !pip install jupyter
# !pip install nbconvert
# !jupyter nbconvert {bypass_file_name}.ibynb --to python
# !rm {bypass_file_name}.ibynb

with open(f"{bypass_file_name}.py", "r") as file:
    exec(file.read())
